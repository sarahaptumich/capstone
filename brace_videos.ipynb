# %% [markdown]
# <a href="https://colab.research.google.com/github/sarahaptumich/capstone/blob/shaptonstall/brace_videos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mount google drive
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Github/capstone/videos
# Out:
# /content/drive/MyDrive/Github/capstone/videos

# %%
# %ls
# Out:
# brace_videos.ipynb  videos_info.csv

# %%
pip install pytube
# Out:
# Collecting pytube
#   Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 920.7 kB/s eta 0:00:00
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0

# %%
import os
from pytube import YouTube
import pandas as pd

# %%
# Define the directory where you want to save the downloaded videos
download_dir = "downloaded_videos"
os.makedirs(download_dir, exist_ok=True)

# Load the video information from the CSV file
videos_info_df = pd.read_csv('videos_info.csv')

# %%
videos_info_df[videos_info_df['video_id']=='2Ui_xim3XXc']
# Out:
#        video_id                                    video_url  year  duration  \
# 57  2Ui_xim3XXc  https://www.youtube.com/watch?v=2Ui_xim3XXc  2018    532.52
#
#      fps resolution
# 57  25.0  1920x1080

# %%
videos_info_df.iloc[57:]
# Out:
#        video_id                                    video_url  year  duration  \
# 57  2Ui_xim3XXc  https://www.youtube.com/watch?v=2Ui_xim3XXc  2018    532.52
# 58  Ow8cbsVCGoE  https://www.youtube.com/watch?v=Ow8cbsVCGoE  2018    398.48
# 59  JwaxirDpmOA  https://www.youtube.com/watch?v=JwaxirDpmOA  2018    246.36
# 60  axnY0XitBIo  https://www.youtube.com/watch?v=axnY0XitBIo  2018    216.00
# 61  ws8ipOc_2hY  https://www.youtube.com/watch?v=ws8ipOc_2hY  2018    342.84
# 62  j_LtCCX-4Yc  https://www.youtube.com/watch?v=j_LtCCX-4Yc  2018    252.36
# 63  aPCmlKU9H70  https://www.youtube.com/watch?v=aPCmlKU9H70  2018    262.92
# 64  g2M6lxqsIvM  https://www.youtube.com/watch?v=g2M6lxqsIvM  2018    407.32
# 65  l2Sb3KlMn3c  https://www.youtube.com/watch?v=l2Sb3KlMn3c  2018    289.80
# 66  ILuhYlZOqcE  https://www.youtube.com/watch?v=ILuhYlZOqcE  2018    375.96
# 67  pdNP0-pSpTQ  https://www.youtube.com/watch?v=pdNP0-pSpTQ  2020    265.68
# 68  jmLSoBxxyhc  https://www.youtube.com/watch?v=jmLSoBxxyhc  2020    338.16
# 69  R6vHm_97eBA  https://www.youtube.com/watch?v=R6vHm_97eBA  2020    275.12
# 70  YRdkxsfoo9c  https://www.youtube.com/watch?v=YRdkxsfoo9c  2020    255.08
# 71  vWRZ6hdlwYo  https://www.youtube.com/watch?v=vWRZ6hdlwYo  2020    290.52
# 72  J8DNK2qLe-s  https://www.youtube.com/watch?v=J8DNK2qLe-s  2020    274.00
# 73  ne_w_zaNOLs  https://www.youtube.com/watch?v=ne_w_zaNOLs  2020    300.76
# 74  x3uelTisF6g  https://www.youtube.com/watch?v=x3uelTisF6g  2020    286.52
# 75  TsucYFPm6Q8  https://www.youtube.com/watch?v=TsucYFPm6Q8  2020    224.36
# 76  zvWiTWT3T2M  https://www.youtube.com/watch?v=zvWiTWT3T2M  2020    239.44
# 77  Pan5R6HxlgI  https://www.youtube.com/watch?v=Pan5R6HxlgI  2020    273.44
# 78  f4PNzVPs5aY  https://www.youtube.com/watch?v=f4PNzVPs5aY  2020    242.88
# 79  qrmkQKLEcAw  https://www.youtube.com/watch?v=qrmkQKLEcAw  2020    339.16
# 80  vgs2VXp78bc  https://www.youtube.com/watch?v=vgs2VXp78bc  2020    295.56
#
#      fps resolution
# 57  25.0  1920x1080
# 58  25.0  1920x1080
# 59  25.0  1920x1080
# 60  25.0  1920x1080
# 61  25.0  1920x1080
# 62  25.0  1920x1080
# 63  25.0  1920x1080
# 64  25.0  1920x1080
# 65  25.0  1920x1080
# 66  25.0  1920x1080
# 67  25.0  1920x1080
# 68  25.0  1920x1080
# 69  25.0  1920x1080
# 70  25.0  1920x1080
# 71  25.0  1920x1080
# 72  25.0  1920x1080
# 73  25.0  1920x1080
# 74  25.0  1920x1080
# 75  25.0  1920x1080
# 76  25.0  1920x1080
# 77  25.0  1920x1080
# 78  25.0  1920x1080
# 79  25.0  1920x1080
# 80  25.0  1920x1080

# %%
# for index, row in videos_info_df.iloc[57:].iterrows():
#     video_url = row['video_url']
#     video_name= str(row['video_id'])+".mp4"
#     try:
#         yt = YouTube(video_url)
#         stream = yt.streams.get_highest_resolution()
#         stream.download(output_path='brace_videos', filename=video_name)
#         print(f"Downloaded '{yt.title}' successfully.")
#     except Exception as e:
#         print(f"Failed to download video {video_name} from {video_url}. Error: {e}")
#         continue
# Out:
# Failed to download video 2Ui_xim3XXc.mp4 from https://www.youtube.com/watch?v=2Ui_xim3XXc. Error: 2Ui_xim3XXc is age restricted, and can't be accessed without logging in.
# Downloaded 'Lil Zoo (AUT) vs. Lil Kev (FRA) | Top 8 | Red Bull BC One World Final 2018' successfully.
# Downloaded 'Victor (USA) vs. Leony (BRA) | Top 16 | Red Bull BC One World Final 2018' successfully.
# Downloaded 'Cri6 (MAR) vs. Dr. Hill (CH) | Top 16 | Red Bull BC One World Final 2018' successfully.
# Downloaded 'Lil Zoo vs. Victor | Semifinal | Red Bull BC One World Final 2018' successfully.
# Downloaded 'Issei (JP) vs. Luka (BRA) | Top 16 | Red Bull BC One World Final 2018' successfully.
# Downloaded 'Sunni (UK) vs. Luigi (USA) | Top 16 | Red Bull BC One World Final 2018' successfully.
# Downloaded 'Issei (JP) vs. Dr.Hill (CH) | Top 8 | Red Bull BC One World Final 2018' successfully.
# Downloaded 'The Wolfer (AUT) vs. Nori (JP) | Top 16 | Red Bull BC One World Final 2018' successfully.
# Downloaded 'Chey (ES) vs. Uzee Rock (UKR) | Top 16 | Red Bull BC One World Final 2018' successfully.
# Downloaded 'B-Girl Madmax vs B-Girl Sunny | Top 8 | Red Bull BC One World Final Austria 2020' successfully.
# Downloaded 'B-Boy Alkolil vs B-Boy Shigekix | Final | Red Bull BC One World Final Austria 2020' successfully.
# Downloaded 'B-Girl Kastet vs B-Girl Mess | Top 8 | Red Bull BC One World Final Austria 2020' successfully.
# Downloaded 'B-Girl Madmax vs B-Girl Jilou | Semifinal | Red Bull BC One World Final Austria 2020' successfully.
# Downloaded 'B-Girl Jilou vs B-Girl Sina | Top 8 | Red Bull BC One World Final Austria 2020' successfully.
# Downloaded 'B-Boy Killa Kolya vs B-Boy Vero | Top 8 | Red Bull BC One World Final Austria 2020' successfully.
# Downloaded 'B-Girl Kastet vs B-Girl Madmax | Final | Red Bull BC One World Final Austria 2020' successfully.
# Downloaded 'B-Boy Shigekix vs B-Boy Kid Karam | Top 8 | Red Bull BC One World Final Austria 2020' successfully.
# Downloaded 'B-Boy Lil Zoo vs B-Boy Philip | Top 8 | Red Bull BC One World Final Austria 2020' successfully.
# Downloaded 'B-Boy Lil Zoo vs B-Boy Alkolil | Semifinal | Red Bull BC One World Final Austria 2020' successfully.
# Downloaded 'B-Boy Shigekix vs B-Boy Vero | Semifinal |Red Bull BC One World Final Austria 2020' successfully.
# Downloaded 'B-Boy Alkolil vs B-Boy Pac Pac | Top 8 | Red Bull BC One World Final Austria 2020' successfully.
# Downloaded 'B-Girl Ayane vs B-Girl Kami | Top 8 | Red Bull BC One World Final Austria 2020' successfully.
# Downloaded 'B-Girl Kastet vs B-Girl Ayane | Semifinal |Red Bull BC One World Final Austria 2020' successfully.
